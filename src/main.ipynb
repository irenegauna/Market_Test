# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod

# Variables constantes
N_ITERACIONES=1000
N_AGENTES=100
PRECIO_INICIAL=200
STOCK_TOTAL=100000
BALANCE_INICIAL=1000
VARIACION_PRECIO=0.005  
RSI_PERIOD=10

class BaseAgente(ABC):
    """Clase base abstracta para los agentes"""
    def __init__(self,tipo):
        self.tipo=tipo
        self.balance=BALANCE_INICIAL
        self.tarjetas=0

    @abstractmethod
    def decidir_accion(self,precio,precio_anterior,historial_precios):
        """Cada agente debe definir su estrategia de compra/venta"""
        pass

class AgenteAleatorio(BaseAgente):
    def __init__(self):
        super().__init__("aleatorio")

    def decidir_accion(self,precio,precio_anterior,historial_precios):
        return random.choices(["comprar","vender","nada"],weights=[0.33,0.33,0.33],k=1)[0]

class AgenteTendencial(BaseAgente):
    def __init__(self):
        super().__init__("tendencial")

    def decidir_accion(self,precio,precio_anterior,historial_precios):
        if precio>=precio_anterior*1.01:
            return random.choices(["comprar","nada"],weights=[0.75,0.25],k=1)[0]
        return random.choices(["vender", "nada"],weights=[0.2, 0.8],k=1)[0]

class AgenteAntiTendencial(BaseAgente):
    def __init__(self):
        super().__init__("anti-tendencial")

    def decidir_accion(self,precio,precio_anterior,historial_precios):
        if precio<=precio_anterior*0.99:
            return random.choices(["comprar","nada"],weights=[0.75,0.25],k=1)[0]
        return random.choices(["vender","nada"],weights=[0.2, 0.8],k=1)[0]

class AgenteLogico(BaseAgente):
    """Agente con estrategia basada en RSI (Relative Strength Index)"""

    def __init__(self):
        super().__init__("logico")
        self.decisiones =[]

    def calcular_rsi(self, historial_precios):
        if len(historial_precios)<RSI_PERIOD+1:
            return 50  # Valor neutral si no hay suficientes datos
        
        ganancias=[max(0,historial_precios[i]-historial_precios[i-1]) for i in range(1,RSI_PERIOD+1)]
        perdidas=[max(0,historial_precios[i-1]-historial_precios[i]) for i in range(1,RSI_PERIOD+1)]
        avg_ganancias=sum(ganancias)/RSI_PERIOD
        avg_perdidas=sum(perdidas)/RSI_PERIOD

        if avg_perdidas==0 and avg_ganancias>0:
            return 100  # RSI máximo
        if avg_perdidas==0 and avg_ganancias==0:
            return 50  # Mercado estable
        
        rs=avg_ganancias/avg_perdidas
        rsi=100-(100/(1+rs))
        return rsi

    def decidir_accion(self,precio,precio_anterior,historial_precios):
        if len(historial_precios)<RSI_PERIOD+1:
            self.decisiones.append(0)
            return "nada"
        
        rsi=self.calcular_rsi(historial_precios[-(RSI_PERIOD+1):])
        
        if rsi<30 and self.balance-precio>=0:
            self.decisiones.append(1)  # Compra
            return "comprar"
        elif rsi>70 and self.tarjetas>0:
            self.decisiones.append(-1)  # Venta
            return "vender"
        
        self.decisiones.append(0)  # No hace nada
        return "nada"

class Mercado:
    """Clase que representa el mercado y la simulación de agentes"""

    def __init__(self):
        self.precio=PRECIO_INICIAL
        self.stock=STOCK_TOTAL
        self.agentes=self.inicializar_agentes()
        self.evolucion_precio=[PRECIO_INICIAL]  # Se agrega el precio inicial

    def inicializar_agentes(self):
        """Crea y devuelve la lista de agentes en el mercado"""
        agentes=[]
        agentes+=[AgenteAleatorio() for _ in range(51)]
        agentes+=[AgenteTendencial() for _ in range(24)]
        agentes+=[AgenteAntiTendencial() for _ in range(24)]
        agentes.append(AgenteLogico())
        return agentes

    def ejecutar_iteracion(self):
        """Ejecuta una iteración del mercado, donde los agentes deciden sus acciones"""
        random.shuffle(self.agentes)
        precio_anterior=self.precio

        for agente in self.agentes:
            accion=agente.decidir_accion(self.precio, precio_anterior, self.evolucion_precio)
            if accion=="comprar" and agente.balance-self.precio>=0 and self.stock>0:
                agente.balance-=self.precio
                agente.tarjetas+=1
                self.stock-=1
                self.precio*=(1+VARIACION_PRECIO)
            elif accion=="vender" and agente.tarjetas>0:
                agente.balance+=self.precio
                agente.tarjetas-=1
                self.stock+=1
                self.precio*=(1-VARIACION_PRECIO)

        self.evolucion_precio.append(self.precio)

    def ejecutar_simulacion(self):
        """Ejecuta la simulación del mercado con todas sus iteraciones"""
        for _ in range(N_ITERACIONES):
            self.ejecutar_iteracion()

    def mostrar_resultados(self):
        """Genera gráficos y muestra balances, incluyendo acciones del Agente Lógico"""
        plt.figure(figsize=(10,5))
        plt.plot(range(N_ITERACIONES+1),self.evolucion_precio,label='Evolución del Precio',color="black")
        plt.xlabel("Iteración")
        plt.ylabel("Precio")
        plt.title("Evolución del precio en el mercado")
        plt.legend()
        plt.show()

        plt.figure(figsize=(10,5))
        plt.plot(range(N_ITERACIONES+1),self.evolucion_precio,label='Evolución del precio',color='black')

        agente_logico=next(agente for agente in self.agentes if isinstance(agente, AgenteLogico))
        compras=[i for i,d in enumerate(agente_logico.decisiones) if d==1]
        ventas=[i for i,d in enumerate(agente_logico.decisiones) if d==-1]

        plt.scatter(compras,[self.evolucion_precio[i] for i in compras],color='green',marker='^',label='Compra')
        plt.scatter(ventas,[self.evolucion_precio[i] for i in ventas],color='red',marker='v',label='Venta')

        plt.legend()
        plt.show()

        balances={}
        for agente in self.agentes:
            if agente.tipo not in balances:
                balances[agente.tipo]=[]
            balances[agente.tipo].append(agente.balance)
        
        promedio_balances={tipo:sum(balances[tipo])/len(balances[tipo]) for tipo in balances}
        df_balances=pd.DataFrame(list(promedio_balances.items()),columns=["Tipo de Agente","Balance Promedio"])
        print(df_balances)
        
        plt.figure(figsize=(8,5))
        bars=plt.bar(df_balances["Tipo de Agente"],df_balances["Balance Promedio"],color=['green','orange','pink','purple'])
        plt.xlabel("Tipo de Agente")
        plt.ylabel("Balance Promedio")
        plt.title("Balance Promedio por Tipo de Agente")
        
        for bar in bars:
            yval=bar.get_height()
            plt.text(bar.get_x()+bar.get_width()/2,yval+10,f"{yval:.2f}",ha='center',fontsize=12)
        
        plt.show()

        for i, agente in enumerate(self.agentes):
            print(f"Agente {i+1}: Tipo={agente.tipo}, Balance Final=${agente.balance:.2f}, Tarjetas={agente.tarjetas}")

# Ejecutar la simulación
mercado=Mercado()
mercado.ejecutar_simulacion()
mercado.mostrar_resultados()
# Out:
#     Tipo de Agente  Balance Promedio
# 0  anti-tendencial        218.597371
# 1       tendencial        880.754666
# 2        aleatorio        919.055560
# 3           logico       1683.117871
# Agente 1: Tipo=anti-tendencial, Balance Final=$227.31, Tarjetas=4
# Agente 2: Tipo=tendencial, Balance Final=$1024.95, Tarjetas=0
# Agente 3: Tipo=aleatorio, Balance Final=$346.61, Tarjetas=4
# Agente 4: Tipo=anti-tendencial, Balance Final=$598.84, Tarjetas=2
# Agente 5: Tipo=aleatorio, Balance Final=$1411.96, Tarjetas=3
# Agente 6: Tipo=anti-tendencial, Balance Final=$93.66, Tarjetas=3
# Agente 7: Tipo=aleatorio, Balance Final=$615.47, Tarjetas=2
# Agente 8: Tipo=tendencial, Balance Final=$1158.55, Tarjetas=0
# Agente 9: Tipo=anti-tendencial, Balance Final=$291.38, Tarjetas=3
# Agente 10: Tipo=anti-tendencial, Balance Final=$280.20, Tarjetas=2
# Agente 11: Tipo=anti-tendencial, Balance Final=$49.82, Tarjetas=4
# Agente 12: Tipo=tendencial, Balance Final=$1022.21, Tarjetas=0
# Agente 13: Tipo=aleatorio, Balance Final=$1537.07, Tarjetas=0
# Agente 14: Tipo=aleatorio, Balance Final=$1189.53, Tarjetas=1
# Agente 15: Tipo=aleatorio, Balance Final=$919.23, Tarjetas=2
# Agente 16: Tipo=anti-tendencial, Balance Final=$594.47, Tarjetas=2
# Agente 17: Tipo=tendencial, Balance Final=$576.53, Tarjetas=2
# Agente 18: Tipo=aleatorio, Balance Final=$1468.61, Tarjetas=0
# Agente 19: Tipo=aleatorio, Balance Final=$1252.01, Tarjetas=0
# Agente 20: Tipo=aleatorio, Balance Final=$13.81, Tarjetas=4
# Agente 21: Tipo=tendencial, Balance Final=$497.44, Tarjetas=1
# Agente 22: Tipo=aleatorio, Balance Final=$1123.55, Tarjetas=2
# Agente 23: Tipo=aleatorio, Balance Final=$1546.19, Tarjetas=0
# Agente 24: Tipo=aleatorio, Balance Final=$849.66, Tarjetas=2
# Agente 25: Tipo=anti-tendencial, Balance Final=$117.60, Tarjetas=3
# Agente 26: Tipo=tendencial, Balance Final=$935.37, Tarjetas=0
# Agente 27: Tipo=aleatorio, Balance Final=$299.05, Tarjetas=4
# Agente 28: Tipo=anti-tendencial, Balance Final=$207.11, Tarjetas=3
# Agente 29: Tipo=aleatorio, Balance Final=$1060.71, Tarjetas=0
# Agente 30: Tipo=tendencial, Balance Final=$1276.93, Tarjetas=0
# Agente 31: Tipo=aleatorio, Balance Final=$736.77, Tarjetas=2
# Agente 32: Tipo=anti-tendencial, Balance Final=$73.61, Tarjetas=3
# Agente 33: Tipo=tendencial, Balance Final=$775.40, Tarjetas=0
# Agente 34: Tipo=anti-tendencial, Balance Final=$251.24, Tarjetas=2
# Agente 35: Tipo=aleatorio, Balance Final=$1080.65, Tarjetas=0
# Agente 36: Tipo=aleatorio, Balance Final=$202.84, Tarjetas=3
# Agente 37: Tipo=anti-tendencial, Balance Final=$237.01, Tarjetas=3
# Agente 38: Tipo=aleatorio, Balance Final=$1180.63, Tarjetas=0
# Agente 39: Tipo=anti-tendencial, Balance Final=$34.47, Tarjetas=4
# Agente 40: Tipo=logico, Balance Final=$1683.12, Tarjetas=6
# Agente 41: Tipo=anti-tendencial, Balance Final=$213.66, Tarjetas=3
# Agente 42: Tipo=aleatorio, Balance Final=$1586.21, Tarjetas=0
# Agente 43: Tipo=anti-tendencial, Balance Final=$225.56, Tarjetas=2
# Agente 44: Tipo=aleatorio, Balance Final=$663.18, Tarjetas=3
# Agente 45: Tipo=aleatorio, Balance Final=$910.16, Tarjetas=3
# Agente 46: Tipo=tendencial, Balance Final=$911.85, Tarjetas=0
# Agente 47: Tipo=tendencial, Balance Final=$496.70, Tarjetas=1
# Agente 48: Tipo=aleatorio, Balance Final=$1487.12, Tarjetas=0
# Agente 49: Tipo=aleatorio, Balance Final=$837.18, Tarjetas=3
# Agente 50: Tipo=aleatorio, Balance Final=$7.50, Tarjetas=3
# Agente 51: Tipo=tendencial, Balance Final=$715.50, Tarjetas=1
# Agente 52: Tipo=aleatorio, Balance Final=$1282.85, Tarjetas=2
# Agente 53: Tipo=anti-tendencial, Balance Final=$226.65, Tarjetas=3
# Agente 54: Tipo=aleatorio, Balance Final=$300.70, Tarjetas=4
# Agente 55: Tipo=anti-tendencial, Balance Final=$115.66, Tarjetas=3
# Agente 56: Tipo=tendencial, Balance Final=$997.37, Tarjetas=0
# Agente 57: Tipo=aleatorio, Balance Final=$153.28, Tarjetas=3
# Agente 58: Tipo=aleatorio, Balance Final=$1619.32, Tarjetas=0
# Agente 59: Tipo=tendencial, Balance Final=$191.52, Tarjetas=2
# Agente 60: Tipo=tendencial, Balance Final=$680.36, Tarjetas=0
# Agente 61: Tipo=anti-tendencial, Balance Final=$335.49, Tarjetas=4
# Agente 62: Tipo=aleatorio, Balance Final=$1344.19, Tarjetas=0
# Agente 63: Tipo=aleatorio, Balance Final=$1058.57, Tarjetas=1
# Agente 64: Tipo=anti-tendencial, Balance Final=$438.94, Tarjetas=2
# Agente 65: Tipo=aleatorio, Balance Final=$322.61, Tarjetas=4
# Agente 66: Tipo=aleatorio, Balance Final=$520.94, Tarjetas=3
# Agente 67: Tipo=aleatorio, Balance Final=$1190.11, Tarjetas=0
# Agente 68: Tipo=aleatorio, Balance Final=$1818.54, Tarjetas=0
# Agente 69: Tipo=aleatorio, Balance Final=$651.95, Tarjetas=2
# Agente 70: Tipo=aleatorio, Balance Final=$1107.50, Tarjetas=2
# Agente 71: Tipo=aleatorio, Balance Final=$635.17, Tarjetas=2
# Agente 72: Tipo=aleatorio, Balance Final=$1378.68, Tarjetas=0
# Agente 73: Tipo=aleatorio, Balance Final=$395.91, Tarjetas=2
# Agente 74: Tipo=aleatorio, Balance Final=$1464.68, Tarjetas=2
# Agente 75: Tipo=aleatorio, Balance Final=$1411.93, Tarjetas=1
# Agente 76: Tipo=aleatorio, Balance Final=$48.31, Tarjetas=6
# Agente 77: Tipo=tendencial, Balance Final=$1165.26, Tarjetas=0
# Agente 78: Tipo=tendencial, Balance Final=$1334.93, Tarjetas=0
# Agente 79: Tipo=aleatorio, Balance Final=$622.21, Tarjetas=5
# Agente 80: Tipo=aleatorio, Balance Final=$1230.35, Tarjetas=0
# Agente 81: Tipo=aleatorio, Balance Final=$421.31, Tarjetas=4
# Agente 82: Tipo=aleatorio, Balance Final=$333.74, Tarjetas=3
# Agente 83: Tipo=tendencial, Balance Final=$1107.47, Tarjetas=0
# Agente 84: Tipo=tendencial, Balance Final=$329.38, Tarjetas=1
# Agente 85: Tipo=aleatorio, Balance Final=$540.85, Tarjetas=3
# Agente 86: Tipo=aleatorio, Balance Final=$1692.30, Tarjetas=0
# Agente 87: Tipo=tendencial, Balance Final=$1205.34, Tarjetas=0
# Agente 88: Tipo=tendencial, Balance Final=$785.96, Tarjetas=0
# Agente 89: Tipo=anti-tendencial, Balance Final=$354.82, Tarjetas=4
# Agente 90: Tipo=anti-tendencial, Balance Final=$98.66, Tarjetas=4
# Agente 91: Tipo=tendencial, Balance Final=$1150.11, Tarjetas=0
# Agente 92: Tipo=aleatorio, Balance Final=$763.66, Tarjetas=4
# Agente 93: Tipo=aleatorio, Balance Final=$1897.77, Tarjetas=0
# Agente 94: Tipo=anti-tendencial, Balance Final=$106.78, Tarjetas=4
# Agente 95: Tipo=tendencial, Balance Final=$888.40, Tarjetas=0
# Agente 96: Tipo=anti-tendencial, Balance Final=$65.67, Tarjetas=3
# Agente 97: Tipo=anti-tendencial, Balance Final=$7.71, Tarjetas=4
# Agente 98: Tipo=tendencial, Balance Final=$1062.98, Tarjetas=0
# Agente 99: Tipo=aleatorio, Balance Final=$338.69, Tarjetas=4
# Agente 100: Tipo=tendencial, Balance Final=$847.59, Tarjetas=1
